# %%
pip install phantomjs
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup
import requests

# %%
url_login = 'https://www.instagram.com/?hl=ru'

session = requests.Session()
session = requests.Session()
r = session.get(url_login, headers = {
    'User-Agent': user_agent_val
})
session.headers.update({'Referer':url_login})
session.headers.update({'User-Agent':user_agent_val})
_xsrf = session.cookies.get('_xsrf', domain="instagram.com")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-087794eddba7> in <module>
#       4 session = requests.Session()
#       5 r = session.get(url_login, headers = {
# ----> 6     'User-Agent': user_agent_val
#       7 })
#       8 session.headers.update({'Referer':url_login})
#
# NameError: name 'user_agent_val' is not defined

# %%
post_request = session.post(url_login, {
     'backUrl': 'https://instagram.com/',
     'username': 'doompro',
     'password': 'doom7139',
     '_xsrf':_xsrf,
})

# %%
def main():
    base_url = 'https://www.instagram.com'
    login = 'https://www.instagram.com/?hl=ru'

    # https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/User-Agent
    # для ваших запросов используйте такую форму:
    #  User-Agent: <название-продукта> / <версия продукта> <комментарий>
    user_agent_val = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) ' \
                 'AppleWebKit/537.36 (KHTML, like Gecko) ' \
                 'Chrome/75.0.3770.142 Safari/537.36'

    # открытие сессии
    session = requests.Session()

    # обновление headers сессии
    session.headers.update({'User-Agent': user_agent})

    # автооризация
    resp = session.post(login, {
        'login': '<логин>',
        'passw': '<пароль>',
        'recaptcha': '<результат-после-успешного-прохождения-капчи>'})

    # запись ответа в файл
    with open('success_login.txt', 'w', encoding='utf-8') as f:
        f.write(str(resp.json()))


if __name__ == "__main__":
    main()

# %%
import requests

from bs4 import BeautifulSoup

client = requests.Session()
headers = {'User-Agent': 'Mozilla/5.0'}
url = 'https://www.instagram.com/accounts/login/'
soup = BeautifulSoup(client.get(url).text, "html.parser")
csrf = soup.find(name="csrf")



url_main = url + 'ajax/'
auth = {'username': 'doompro', 'password': 'doom7139'}
headers = {'referer': "https://www.instagram.com/accounts/login/"}



with requests.Session() as s:
    req = s.get(url)
    headers = {'User-Agent': 'Mozilla/5.0'}
    s.post(url_main, data=auth, headers=headers)
    # Now, you can use 's' object to 'get' response from any instagram url
    # as a logged in user.
    r = s.get('https://www.instagram.com/accounts/edit/')
    # If you want to check whether you're getting the correct response,
    # you can use this:
    print(auth['username'] in r.text)  # which returns 'True'

# %%
username = "doompro"
password = "doom7139"

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import re

driver = webdriver.PhantomJS()
driver.get("http://insta.friendorfollow.com")
driver.find_elements_by_tag_name("a")[1].click()

print("Perimene file....".upper())
driver.find_element_by_name('username').send_keys(username)
driver.find_element_by_name('password').send_keys(password)
driver.find_element_by_class_name("button-green").click()

try: driver.find_elements_by_name("allow")[1].click()
except:
    pass
regv = 'data-id=\"([0-9]*)\"'
f = open(username+".txt", 'w')
malakes = re.findall(regv, driver.page_source)[::-1]
for malakas in malakes:
    print( malakas)

f.close()
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# B:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      71             cmd.extend(self.command_line_args())
# ---> 72             self.process = subprocess.Popen(cmd, env=self.env,
#      73                                             close_fds=platform.system() != 'Windows',
#
# B:\ProgramData\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     853
# --> 854             self._execute_child(args, executable, preexec_fn, close_fds,
#     855                                 pass_fds, cwd, env,
#
# ...

# %%
import requests

url = 'https://www.instagram.com/accounts/login/'
url_main = url + 'ajax/'
req1 = requests.get(url)
auth = {'username': 'doompro', 'password': 'doom7139'}
headers = {
    'origin': "https://www.instagram.com",
    'x-instagram-ajax': "1",
    'content-type': "application/x-www-form-urlencoded",
    'accept': "*/*",
    'x-requested-with': "XMLHttpRequest",
    'user-agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.167 Safari/537.36",
    'referer': "https://www.instagram.com/accounts/login/",
    'accept-encoding': "gzip, deflate, br",
    'accept-language': "ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7",
    'cookie': "fbm_124024574287414=base_domain=.instagram.com; ig_or=landscape-primary; ig_pr=1; ig_vw=1920; mid=Wcp3vAALAAGjSka8GEnPwijnia6-; rur=FTW; ig_vh=949; fbsr_124024574287414=jSVsTpoGuOgZQB0vEP_X70hrO2-LlfD9EnUz9nwGTXo....",
    'x-compress': "null",
    'cache-control': "no-cache"
}
req2 = requests.post(url_main,data=auth,headers=headers)
sessionid = req2.cookies['sessionid']

print(req2.content)
print(req2.cookies['ds_user_id'])
print(req2.cookies['sessionid'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-ee7f1fdbf4cd> in <module>
#      20 }
#      21 req2 = requests.post(url_main,data=auth,headers=headers)
# ---> 22 sessionid = req2.cookies['sessionid']
#      23
#      24 print(req2.content)
#
# B:\ProgramData\Anaconda3\lib\site-packages\requests\cookies.py in __getitem__(self, name)
#     326         .. warning:: operation is O(n), not O(1).
#     327         """
# --> 328         return self._find_no_duplicates(name)
#     329
#     330     def __setitem__(self, name, value):
#
# B:\ProgramData\Anaconda3\lib\site-packages\requests\cookies.py in _find_no_duplicates(self, name, domain, path)
#     397         if toReturn:
#     398             return toReturn
# --> 399         raise KeyError('name=%r, domain=%r, path=%r' % (name, domain, path))
#     400
#     401     def __getstate__(self):
#
# ...

# %%
# Out:
#   File "<ipython-input-16-58ad1cc2194d>", line 1
#     pip install selenium
#         ^
# SyntaxError: invalid syntax

# %%
from time import sleep
from selenium import webdriver

browser = webdriver.Firefox()
browser.get('https://www.instagram.com/')
sleep(5)
browser.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# B:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      71             cmd.extend(self.command_line_args())
# ---> 72             self.process = subprocess.Popen(cmd, env=self.env,
#      73                                             close_fds=platform.system() != 'Windows',
#
# B:\ProgramData\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     853
# --> 854             self._execute_child(args, executable, preexec_fn, close_fds,
#     855                                 pass_fds, cwd, env,
#
# ...

# %%
pip install firefox-geckodriver
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement firefox-geckodriver (from versions: none)
# ERROR: No matching distribution found for firefox-geckodriver

# %%
import re
import requests
from bs4 import BeautifulSoup

from datetime import datetime

link = 'https://www.instagram.com'
login_url = 'https://www.instagram.com/?hl=ru'

time = int(datetime.now().timestamp())

payload = {
    'username': 'doompro',
    'enk-password': f'#PWD_INSTAGRAM_BROWSER:0:{time}: doom7139',  # <-- note the '0' - that means we want to use plain passwords
    'queryParams': {},
    'optIntoOneTap': 'false'
}

with requests.Session() as s:
    r = s.get(link)
    r = s.post(login_url,data=payload,headers={
        "user-agent": "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.120 Safari/537.36",
        "x-requested-with": "XMLHttpRequest",
        "referer": "https://www.instagram.com/accounts/login/"
    })
    print(r.status_code)
    print(r.url)
    print(r.text)
# Out:
# 403
# https://www.instagram.com/?hl=ru
# <!DOCTYPE html>
# <html lang="ru" class="no-js not-logged-in ">
#     <head>
#         <meta charset="utf-8">
#         <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
#         <title>
#                   Страница не найдена &bull; Instagram
#                 </title>
#
#
#         <meta name="robots" content="noimageindex, noarchive">
#         <meta name="apple-mobile-web-app-status-bar-style" content="default">
#         <meta name="mobile-web-app-capable" content="yes">
#         <meta name="theme-color" content="#ffffff">
#         <meta id="viewport" name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1, viewport-fit=cover">
#         <link rel="manifest" href="/data/manifest.json">
#
#
#
#
#
#         <script type="text/javascript">
#         (function() {
#   var docElement = document.documentElement;
#   var classRE = new RegExp('(^|\\s)no-js(\\s|$)');
# ...
