# %%
import requests
import datetime
from bs4 import BeautifulSoup
import pandas as pd
import xmltodict

# %% [markdown]
# Домашнее задание к лекции "Основы веб-скрапинга и работы с API"
# Задание 1.
# Обязательная часть
# Будем парсить страницу со свежеми новостям на habr.com/ru/all/.
#
# Вам необходимо собирать только те статьи, в которых встречается хотя бы одно требуемое ключевое слово. Эти слова определяем в начале кода в переменной, например:
#
# KEYWORDS = ['python', 'парсинг']
#
# Поиск вести по всей доступной preview-информации (это информация, доступная непосредственно с текущей страницы).
#
# В итоге должен формироваться датафрейм вида: <дата> - <заголовок> - <ссылка>
#
# Дополнительная часть (необязательная)
# Улучшить скрипт так, чтобы он анализировал не только preview-информацию статьи, но и весь текст статьи целиком.
#
# Для этого потребуется получать страницы статей и искать по тексту внутри этой страницы.
#
# Итоговый датафрейм формировать со столбцами: <дата> - <заголовок> - <ссылка> - <текст_статьи>

# %%
Posts_table = pd.DataFrame()
post_id_list = []
post_data_list = []
post_title_list = []
post_link_list = []
keywords_list = []
def POST_ID_with_keywords(posts, x):
    global post_id_list
    global keywords_list
    for post in posts:
        post_id = post.parent.attrs.get('id')
        post_id = int(post_id.split('_')[-1])
        post_id_list.append(post_id)
        keywords_list.append(x)
    if not post_id:
        post_id = 'Нет данных'
        post_id_list.append(post_id)
        keywords_list.append(x)
        
def POST_DATE(posts):
    global post_data_list
    for post in posts:
        post_data = post.find('span', class_='post__time')
        post_data_list.append(post_data.text)
    if not post_data:
        post_data = 'Нет данных'
        post_data_list.append(post_data)
        
def POST_TITLE(posts):
    global post_title_list
    for post in posts:
        post_title = post.find('a', class_='post__title_link')
        post_title_list.append(post_title.text)
    if not post_title:
        post_title = 'Нет данных'
        post_title_list.append(post_title)

def POST_LINK(posts):
    global post_links_list
    for post in posts:
        post_link = post.find('a').get('href')
        post_link_list.append(post_link)
    if not post_link:
        post_link = 'Нет данных'
        post_link_list.append(post_link)
        
        

KEYWORDS = ['python', 'парсинг', 0]
URL = 'https://habr.com/ru/all/'
for x in KEYWORDS :
    if x != 0 :
        params = {
        'search-form__field': x}
        res = requests.get(URL, params)
        params_for_time = {
            'toggle-menu__item-link' : 'по времени'
        }
        res_sorted = requests.get(res.url, params_for_time )
        soup = BeautifulSoup(res_sorted.text, 'html.parser')
        posts = soup.find_all('article', class_='post')
        POST_ID_with_keywords(posts, x)
        POST_DATE(posts)
        POST_TITLE(posts)
        POST_LINK(posts)
list_post = list(zip(post_id_list , keywords_list , post_title_list , post_data_list , post_link_list))
row = 0 
while row < len(list_post) :
    _row_ = {'Post ID' : list_post[row][0] , 'Post keyword': list_post[row][1] , 'Post title': list_post[row][2] , 'Post date' : list_post[row][3] , "Post link" : list_post[row][4]}
    Posts_table = pd.concat([Posts_table, pd.DataFrame([_row_])]) 
    row += 1
print(Posts_table)
# Out:
#    Post ID Post keyword                                         Post title  \
# 0   522738       python  Завтрак с легендарным геймдизайнером Американо...
# 0   522782       python  Что такое хорошо, что такое плохо: будет ли со...
# 0   522850       python  Как приручить событийно-ориентированные микрос...
# 0   522616       python  «Что угодно кроме алгоритмов»: где искать музы...
# 0   522844       python                    Создание favicon для сайта 2020
# 0   522814       python  Карбюраторы мотоциклетного типа. Главная дозир...
# 0   522832       python  Два «вечных» подхода к управлению собственным ...
# 0   522828       python  Определяем направление на аэропорт с помощью R...
# 0   522826       python  Жизнь айтишника в Буэнос-Айресе: карьера в IT,...
# 0   522808       python                      MIDI2USB – музыка нас связала
# 0   522818       python  Еще подробнее: что нужно знать о внутриканальн...
# 0   522816       python            Структурное против ООП программирование
# 0   522810       python         Zen 3 – Король умер, да здравствует король
# 0   522804       python               Великолепный Марио: рождение легенды
# 0   522648       python                            RubyGems Digest 2020·09
# 0   522802       python  Big Data Tools EAP 11: Zeppelin в DataGrip и s...
# 0   522794       python        Релиз Dart 2.10: на шаг ближе к null-safety
# 0   522798       python                   Как проводить one-to-one встречи
# 0   522792       python  # Вышел релиз GitLab 13.4 с хранилищем HashiCo...
# 0   522738      парсинг  Завтрак с легендарным геймдизайнером Американо...
# 0   522782      парсинг  Что такое хорошо, что такое плохо: будет ли со...
# 0   522850      парсинг  Как приручить событийно-ориентированные микрос...
# 0   522616      парсинг  «Что угодно кроме алгоритмов»: где искать музы...
# 0   522844      парсинг                    Создание favicon для сайта 2020
# 0   522814      парсинг  Карбюраторы мотоциклетного типа. Главная дозир...
# 0   522832      парсинг  Два «вечных» подхода к управлению собственным ...
# 0   522828      парсинг  Определяем направление на аэропорт с помощью R...
# 0   522826      парсинг  Жизнь айтишника в Буэнос-Айресе: карьера в IT,...
# 0   522808      парсинг                      MIDI2USB – музыка нас связала
# 0   522818      парсинг  Еще подробнее: что нужно знать о внутриканальн...
# 0   522816      парсинг            Структурное против ООП программирование
# 0   522810      парсинг         Zen 3 – Король умер, да здравствует король
# 0   522804      парсинг               Великолепный Марио: рождение легенды
# 0   522648      парсинг                            RubyGems Digest 2020·09
# 0   522802      парсинг  Big Data Tools EAP 11: Zeppelin в DataGrip и s...
# 0   522794      парсинг        Релиз Dart 2.10: на шаг ближе к null-safety
# 0   522798      парсинг                   Как проводить one-to-one встречи
# 0   522792      парсинг  # Вышел релиз GitLab 13.4 с хранилищем HashiCo...
#
#          Post date                                   Post link
# 0  сегодня в 12:15   https://habr.com/ru/users/galimova_ruvds/
# 0  сегодня в 12:13             https://habr.com/ru/users/lodz/
# 0  сегодня в 10:50          https://habr.com/ru/users/camunar/
# 0  сегодня в 10:35         https://habr.com/ru/users/Audioman/
# 0  сегодня в 08:05        https://habr.com/ru/users/HoroSamiK/
# 0  сегодня в 07:26  https://habr.com/ru/users/enthusiast-next/
# 0    вчера в 23:44  https://habr.com/ru/users/Account_NIISOKB/
# 0    вчера в 23:33      https://habr.com/ru/users/DmitrySpb79/
# 0    вчера в 22:39         https://habr.com/ru/users/alexlash/
# 0    вчера в 22:20           https://habr.com/ru/users/Costic/
# 0    вчера в 22:12         https://habr.com/ru/users/Audioman/
# 0    вчера в 21:51         https://habr.com/ru/users/xverizex/
# 0    вчера в 21:20      https://habr.com/ru/users/RiddleRider/
# 0    вчера в 21:09   https://habr.com/ru/users/WesternDigital/
# 0    вчера в 19:52          https://habr.com/ru/users/tin_vsl/
# 0    вчера в 19:35         https://habr.com/ru/users/olegchir/
# 0    вчера в 19:07        https://habr.com/ru/users/Wriketeam/
# 0    вчера в 18:56           https://habr.com/ru/users/akpsyh/
# 0    вчера в 18:11           https://habr.com/ru/users/aionin/
# 0  сегодня в 12:15   https://habr.com/ru/users/galimova_ruvds/
# 0  сегодня в 12:13             https://habr.com/ru/users/lodz/
# 0  сегодня в 10:50          https://habr.com/ru/users/camunar/
# 0  сегодня в 10:35         https://habr.com/ru/users/Audioman/
# 0  сегодня в 08:05        https://habr.com/ru/users/HoroSamiK/
# 0  сегодня в 07:26  https://habr.com/ru/users/enthusiast-next/
# 0    вчера в 23:44  https://habr.com/ru/users/Account_NIISOKB/
# 0    вчера в 23:33      https://habr.com/ru/users/DmitrySpb79/
# 0    вчера в 22:39         https://habr.com/ru/users/alexlash/
# 0    вчера в 22:20           https://habr.com/ru/users/Costic/
# 0    вчера в 22:12         https://habr.com/ru/users/Audioman/
# 0    вчера в 21:51         https://habr.com/ru/users/xverizex/
# 0    вчера в 21:20      https://habr.com/ru/users/RiddleRider/
# 0    вчера в 21:09   https://habr.com/ru/users/WesternDigital/
# 0    вчера в 19:52          https://habr.com/ru/users/tin_vsl/
# 0    вчера в 19:35         https://habr.com/ru/users/olegchir/
# 0    вчера в 19:07        https://habr.com/ru/users/Wriketeam/
# 0    вчера в 18:56           https://habr.com/ru/users/akpsyh/
# 0    вчера в 18:11           https://habr.com/ru/users/aionin/

# %% [markdown]
# Задание 2.¶
# Обязательная часть
# Написать скрипт, который будет проверять список e-mail адресов на утечку при помощи сервиса Avast Hack Ckeck. Список email-ов задаем переменной в начале кода:
# EMAIL = [xxx@x.ru, yyy@y.com]
#
# В итоге должен формироваться датафрейм со столбцами: <почта> - <дата утечки> - <источник утечки> - <описание утечки>
#
# Подсказка: сервис работает при помощи "скрытого" API. Внимательно изучите post-запросы.
#
# Дополнительная часть (необязательная)
# Написать скрипт, который будет получать 50 последних постов указанной группы во Вконтакте.
# Документация к API VK: https://vk.com/dev/methods , вам поможет метод wall.get
#
# GROUP = 'netology'
# TOKEN = УДАЛЯЙТЕ В ВЕРСИИ ДЛЯ ПРОВЕРКИ, НА GITHUB НЕ ВЫКЛАДЫВАТЬ
# В итоге должен формироваться датафрейм со столбцами: <дата поста> - <текст поста>
#
# ПРИМЕЧАНИЕ
# Домашнее задание сдается ссылкой на репозиторий GitHub. Не сможем проверить или помочь, если вы пришлете:
#
# файлы;
# архивы;
# скриншоты кода.
# Все обсуждения и консультации по выполнению домашнего задания ведутся только на соответствующем канале в slack.
#
# Как правильно задавать вопросы аспирантам, преподавателям и коллегам?
# Прежде чем задать вопрос необходимо попробовать найти ответ самому в интернете. Навык самостоятельного поиска информации – один из важнейших, и каждый практикующий специалист любого уровня это делает каждый день.
#
# Любой вопрос должен быть сформулирован по алгоритму:
# 1) Что я делаю?
# 2) Какого результата я ожидаю?
# 3) Как фактический результат отличается от ожидаемого?
# 4) Что я уже попробовал сделать, чтобы исправить проблему?
#
# По возможности, прикрепляйте к вопросу скриншоты, либо ссылки на код. Оставляйте только проблемный и воспроизводимый участок кода, все решение выкладывать не допускается.

# %%
EMAIL = ['xxx@x.ru', 'yyy@y.com'] 
url = "https://digibody.avast.com/v1/web/leaks"
AV = pd.DataFrame()
for email in EMAIL:
    result = requests.post(url, json={"email" : email})
    for _ in result.json()['value']:
        row = {'email': email,
                'date': _['leak_info']['date'],
                'title': _['leak_info']['title'], 
                'description': _['leak_info']['description']}
        AV = pd.concat([AV, pd.DataFrame([row])])
AV
# Out:
#        email           date                                 title  \
# 0   xxx@x.ru  1513900800000  Combolist of 1.4 Billion Credentials
# 0   xxx@x.ru  1549411200000              Collection #4 Combo List
# 0   xxx@x.ru  1485820800000                        CD Projekt Red
# 0   xxx@x.ru  1487030400000                                Parapa
# 0   xxx@x.ru  1599696000000                    Ga$$Pacc Combolist
# 0   xxx@x.ru  1488931200000                      Sensitive Source
# 0   xxx@x.ru  1549411200000              Collection #5 Combo List
# 0   xxx@x.ru  1549411200000            2019 Antipublic Combo List
# 0   xxx@x.ru  1487030400000                            CFire Mail
# 0   xxx@x.ru  1477008000000                         Adobe Systems
# 0   xxx@x.ru  1548720000000              Collection #2 Combo List
# 0   xxx@x.ru  1477699200000                                    VK
# 0   xxx@x.ru  1548374400000              Collection #1 Combo List
# 0   xxx@x.ru  1477180800000                                 iMesh
# 0  yyy@y.com  1513900800000  Combolist of 1.4 Billion Credentials
# 0  yyy@y.com  1508284800000                 Anti-Public Combolist
# 0  yyy@y.com  1549411200000              Collection #4 Combo List
# 0  yyy@y.com  1477267200000                      Sensitive Source
# 0  yyy@y.com  1560384000000                                 Canva
# 0  yyy@y.com  1477267200000                               Dropbox
# 0  yyy@y.com  1488326400000                                 Rayli
# 0  yyy@y.com  1578528000000                      Sensitive Source
# 0  yyy@y.com  1601510400000                      Sensitive Source
# 0  yyy@y.com  1549411200000            2019 Antipublic Combo List
# 0  yyy@y.com  1509753600000                            MyHeritage
# 0  yyy@y.com  1477008000000                         Adobe Systems
# 0  yyy@y.com  1548720000000              Collection #2 Combo List
# 0  yyy@y.com  1590624000000                              Wishbone
# 0  yyy@y.com  1489536000000               Global Reach Technology
# 0  yyy@y.com  1477353600000                      Sensitive Source
# 0  yyy@y.com  1545350400000                      Sensitive Source
# 0  yyy@y.com  1523318400000                      Sensitive Source
# 0  yyy@y.com  1477008000000                              LinkedIn
# 0  yyy@y.com  1490313600000                                 Youku
# 0  yyy@y.com  1578009600000                             AZCentral
# 0  yyy@y.com  1518912000000                                Netlog
# 0  yyy@y.com  1593043200000        "Cash Cloud" Retail Combo List
# 0  yyy@y.com  1581552000000                      Sensitive Source
# 0  yyy@y.com  1477180800000                                 iMesh
#
#                                          description
# 0  The proliferation of stolen or leaked database...
# 0  On January 7, 2019, an online user named Sanix...
# 0  In March 2016, CDProjektRed.com.com's forum da...
# 0  In July and August 2016, two criminals execute...
# 0  This is a compilation of files including breac...
# 0  This source has been marked as sensitive due t...
# 0  On January 7, 2019, an online user named Sanix...
# 0  On January 7, 2019, an online user named Sanix...
# 0  In July and August of 2016, two criminals carr...
# 0  In October of 2013, criminals penetrated Adobe...
# 0  On January 7, 2019, an online user named Sanix...
# 0  Popular Russian social networking platform VKo...
# 0  On January 7, 2019, an online user named Sanix...
# 0  In June 2016, a cache of over 51 million user ...
# 0  The proliferation of stolen or leaked database...
# 0  The proliferation of stolen or leaked database...
# 0  On January 7, 2019, an online user named Sanix...
# 0  This source has been marked as sensitive due t...
# 0  In May 2019, graphic-design site Canva's datab...
# 0  Cloud storage company Dropbox suffered a major...
# 0  On an unconfirmed date, Chinese gossip site Ra...
# 0  This source has been marked as sensitive due t...
# 0  This source has been marked as sensitive due t...
# 0  On January 7, 2019, an online user named Sanix...
# 0  In October 2017, a customer database belonging...
# 0  In October of 2013, criminals penetrated Adobe...
# 0  On January 7, 2019, an online user named Sanix...
# 0  In January 2020, the online poll website Wishb...
# 0  In 2016, Global Reach Technology's database wa...
# 0  This source has been marked as sensitive due t...
# 0  This source has been marked as sensitive due t...
# 0  This source has been marked as sensitive due t...
# 0  In 2012, online professional networking platfo...
# 0  Youku is a large Chinese video content company...
# 0  At an unconfirmed date, online Arizona newspap...
# 0  Netlog (formerly known as Facebox and Bingbox)...
# 0  At an unconfirmed date, this "Cash Cloud" Reta...
# 0  This source has been marked as sensitive due t...
# 0  In June 2016, a cache of over 51 million user ...
