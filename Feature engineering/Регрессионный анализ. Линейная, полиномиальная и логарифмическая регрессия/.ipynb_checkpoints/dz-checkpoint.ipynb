# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv( 'adult.csv' )
data.drop(['fnlwgt', 'educational-num'], axis='columns', inplace=True)
columns = list(data.columns)
data = data.replace("?", np.nan)
data.head()
# Out:
#    age  workclass     education      marital-status         occupation  \
# 0   25    Private          11th       Never-married  Machine-op-inspct
# 1   38    Private       HS-grad  Married-civ-spouse    Farming-fishing
# 2   28  Local-gov    Assoc-acdm  Married-civ-spouse    Protective-serv
# 3   44    Private  Some-college  Married-civ-spouse  Machine-op-inspct
# 4   18        NaN  Some-college       Never-married                NaN
#
#   relationship   race  gender  capital-gain  capital-loss  hours-per-week  \
# 0    Own-child  Black    Male             0             0              40
# 1      Husband  White    Male             0             0              50
# 2      Husband  White    Male             0             0              40
# 3      Husband  Black    Male          7688             0              40
# 4    Own-child  White  Female             0             0              30
#
#   native-country income
# 0  United-States  <=50K
# 1  United-States  <=50K
# ...

# %%
for x in columns:
    print(f'Для {x} пустых строк {len( data[ pd.isnull( data[x] ) ] )}')
### Мог сразу заменить на nan, но решил , что так быстее писать 
data = data.replace(np.nan, 0)
# Out:
# Для age пустых строк 0
# Для workclass пустых строк 2799
# Для education пустых строк 0
# Для marital-status пустых строк 0
# Для occupation пустых строк 2809
# Для relationship пустых строк 0
# Для race пустых строк 0
# Для gender пустых строк 0
# Для capital-gain пустых строк 0
# Для capital-loss пустых строк 0
# Для hours-per-week пустых строк 0
# Для native-country пустых строк 857
# Для income пустых строк 0

# %%
Data_L = pd.get_dummies( data, columns = [ 'workclass', 'education', 'marital-status', 'occupation','relationship', 'race', 'gender', 'native-country'  ] )

# %%
columns = print(list(Data_L.columns))
# Out:
# ['age', 'capital-gain', 'capital-loss', 'hours-per-week', 'income', 'workclass_0', 'workclass_Federal-gov', 'workclass_Local-gov', 'workclass_Never-worked', 'workclass_Private', 'workclass_Self-emp-inc', 'workclass_Self-emp-not-inc', 'workclass_State-gov', 'workclass_Without-pay', 'education_10th', 'education_11th', 'education_12th', 'education_1st-4th', 'education_5th-6th', 'education_7th-8th', 'education_9th', 'education_Assoc-acdm', 'education_Assoc-voc', 'education_Bachelors', 'education_Doctorate', 'education_HS-grad', 'education_Masters', 'education_Preschool', 'education_Prof-school', 'education_Some-college', 'marital-status_Divorced', 'marital-status_Married-AF-spouse', 'marital-status_Married-civ-spouse', 'marital-status_Married-spouse-absent', 'marital-status_Never-married', 'marital-status_Separated', 'marital-status_Widowed', 'occupation_0', 'occupation_Adm-clerical', 'occupation_Armed-Forces', 'occupation_Craft-repair', 'occupation_Exec-managerial', 'occupation_Farming-
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit( Data_L['income'] )
from sklearn.model_selection import train_test_split
X , data_test = train_test_split(Data_L, test_size=0.2)
y = pd.Series( data = le.transform( X['income'] ) )
del X['income']
y_test = pd.Series( data = le.transform( data_test['income'] ) )
del data_test['income']
X.head()
# Out:
#        age  capital-gain  capital-loss  hours-per-week  workclass_0  \
# 10977   36             0             0              50            0
# 6823    20             0             0              35            0
# 3419    21             0             0              40            0
# 40033   36             0             0              40            0
# 43528   59             0             0              50            0
#
#        workclass_Federal-gov  workclass_Local-gov  workclass_Never-worked  \
# 10977                      0                    0                       0
# 6823                       0                    0                       0
# 3419                       0                    0                       0
# 40033                      0                    0                       0
# 43528                      0                    0                       0
#
#        workclass_Private  workclass_Self-emp-inc  ...  \
# ...

# %%
from sklearn.linear_model import LinearRegression
model = LogisticRegression()
model.fit( X, y )
predictions = model.predict_proba( data_test )
# Out:
# B:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
model.score(data_test, y_test)
# Out:
# 0.8517760262053434
